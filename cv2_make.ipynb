# %% [markdown]
# <a href="https://colab.research.google.com/github/MQsparrow/openCV/blob/main/cv2_make.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
m1 = cv2.imread("h2.png",1)
m3 = cv2.inRange(m1, (0, 0, 255), (0, 0, 255))
m3 = cv2.bitwise_not(m3)
cv2_imshow(m3)
# Out:
# <PIL.Image.Image image mode=L size=1087x612 at 0x7F054E96C850>
